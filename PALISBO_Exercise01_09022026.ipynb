# %% [markdown]
# <a href="https://colab.research.google.com/github/merbiji/Computational-Physics/blob/main/PALISBO_Exercise01_09022026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. - 2.

# %%
x = 2
y = 3
del x

print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2669/2986965966.py in <cell line: 0>()
#       3 del x
#       4
# ----> 5 print(x)
#       6
#
# NameError: name 'x' is not defined

# %% [markdown]
# 3 - 4

# %%
import math as mat
x = 10
y = 3
u = x + y
v = x*y
w = x/y
z = mat.sin(x)
r = 8*mat.sin(x)
s = 5*mat.sin(x*y)
p = x**y

print(u,v,w,z,r,s,p)
# %whos
# Out:
# 13 30 3.3333333333333335 -0.5440211108893698 -4.352168887114958 -4.940158120464309 1000
# Variable   Type      Data/Info
# ------------------------------
# mat        module    <module 'math' (built-in)>
# p          int       1000
# r          float     -4.352168887114958
# s          float     -4.940158120464309
# u          int       13
# v          int       30
# w          float     3.3333333333333335
# x          int       10
# y          int       3
# z          float     -0.5440211108893698

# %% [markdown]
# 5.

# %%
S = "123"
N = float(S)

print(type(S), type(N))
# Out:
# <class 'str'> <class 'float'>

# %% [markdown]
# 6.

# %%
s1 = "HELLO"
s2 = "hello"

print(s1==s2)
print(s1.lower() == s2)
print(s1 == s2.upper())
# Out:
# False
# True
# True

# %% [markdown]
# 7.

# %%
w1 = "Engineering"
w2 = "Book"

print(f"The word {w1} has {len(w1)} letters.")
print(f"The word {w2} has {len(w2)} letters.")
# Out:
# The word Engineering has 11 letters.
# The word Book has 4 letters.

# %% [markdown]
# 8. - 9.

# %%
S = "Python is great!"
"Python" in S
# Out:
# "Python" in S

# %% [markdown]
# 9.

# %%
S = "Python is great!"
W = S[-6:-1]
print(W)
# Out:
# great

# %% [markdown]
# 10. - 11.

# %%
list_a = [1,8,9,15]
list_a.insert(1, 2)
list_a.append(4)
list_a.sort()
print(list_a)
# Out:
# [1, 2, 4, 8, 9, 15]

# %% [markdown]
# 12.

# %%
S = "Python is great!"
list(S)
# Out:
# ['P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'g',
#  'r',
#  'e',
#  'a',
#  't',
#  '!']

# %% [markdown]
# 13. - 14.

# %%
tuple_a = ("One", 1,)

tuple_a[2]
# Out:
# 3

# %% [markdown]
# 15.

# %%
S = (2,3,2,3,1,2,5)
print(set(S))
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# 16.

# %%
set_a = set((2,3,2))
set_b = set((1,2,3))
print(set_a.union(set_b))
print(set_a.intersection(set_b))
print(set_a.difference(set_b))
# Out:
# {1, 2, 3}
# {2, 3}
# set()

# %% [markdown]
# 17. - 18.

# %%
my_dictionary = {"A":"a", "B":"b", "C":"c"}
print(my_dictionary.keys())
print("B" in my_dictionary)
# Out:
# dict_keys(['A', 'B', 'C'])
# True

# %% [markdown]
# 19.

# %%
import numpy as np
x = np.array([1,4,3,2,9,4])
y = np.array([2,3,4,1,2,3])

u = x + y
v = x*y
w = x/y
z = np.sin(x)
r = 8*np.sin(x)
s = 5*np.sin(x*y)
p = x**y

print(u,v,w,z,r,s,p)
# Out:
# [ 3  7  7  3 11  7] [ 2 12 12  2 18 12] [0.5        1.33333333 0.75       2.         4.5        1.33333333] [ 0.84147098 -0.7568025   0.14112001  0.90929743  0.41211849 -0.7568025 ] [ 6.73176788 -6.05441996  1.12896006  7.27437941  3.29694788 -6.05441996] [ 4.54648713 -2.68286459 -2.68286459  4.54648713 -3.75493623 -2.68286459] [ 1 64 81  2 81 64]

# %% [markdown]
# 20.

# %%
import numpy as np

array = np.linspace(-10, 10 , 100)
print(array)
# Out:
# [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...
